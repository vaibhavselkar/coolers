# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Sales.csv")
df.head()
# Out:
#    Sr. No       Date              Name      Address    Model  Size  \
# 0       1  16/03/2022  Pradeep Thakare        Tigaon  Desert   3.5
# 1       2  16/03/2022             Motu  Dwarakanagar  Desert   4.5
# 2       3  16/03/2022             Motu  Dwarakanagar    Duct   4.5
# 3       4  19/03/2022    Prashant bhau   Shantinagar    Duct   4.5
# 4       5  19/03/2022         Ramnagar      Ramnagar  Desert   3.5
#
#         Total    Payment  Remaining  Mode of Payment        Phone
# 0   ₹5,200.00   ₹5,200.00      ₹0.00            Cash          NaN
# 1   ₹5,200.00   ₹5,200.00      ₹0.00            Cash   7620273708
# 2   ₹7,000.00   ₹7,000.00      ₹0.00             Cash  7620273708
# 3  ₹11,800.00  ₹11,800.00      ₹0.00             Cash  8308050664
# 4   ₹5,500.00   ₹5,500.00      ₹0.00             Cash         NaN

# %%
desert_counts = df[df["Model"] == "Desert"]["Size"].value_counts()
print(desert_counts)
# Out:
# 3.5    25
# 4.5     8
# 2.5     8
# Name: Size, dtype: int64

# %%
# Total sales of Desert
desert_counts = df[df["Model"] == "Desert"]["Size"].value_counts()

# Plotting a bar chart
plt.figure(figsize=(10, 6))
desert_counts.plot(kind='bar', color='skyblue')
plt.title('Count of Desert Cooler')
plt.xlabel('Desert Model')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Adjust rotation for better visibility
plt.show()

# %%
#Total sales of Ducts
duct_counts = df[df["Model"] == "Duct"]["Size"].value_counts()

# Plotting a bar chart
plt.figure(figsize=(10, 6))
duct_counts.plot(kind='bar', color='skyblue')
plt.title('Count of Desert Cooler')
plt.xlabel('Desert Model')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Adjust rotation for better visibility
plt.show()

# %%
data = pd.read_csv("Max sales.csv")
data.head()
# Out:
#             Size  Total
# 0  Desert 2.5 ft  10700
# 1  Desert 3.5 ft  65950
# 2    Desert 4 ft  41200
# 3       Duct 300  30800
# 4       Duct 500  82250

# %%
# Revenue of Coolers
plt.figure(figsize=(8, 8))
plt.pie(data['Total'], labels=data['Size'], autopct='%1.1f%%', startangle=90)
plt.title('Top Sizes by Total')
plt.show()
